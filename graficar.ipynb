# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.DataFrame(np.random.randint(200, size=(50,4)), columns=['a','b','c','d'])

# %%
dataframe
# Out:
#       a    b    c    d
# 0    99  197  143   22
# 1    27   32  106    6
# 2   127   32  118   85
# 3   147  114   15  164
# 4    80  176   63   80
# 5   197  174  137   28
# 6   117   23  118  181
# 7    62   34   32  186
# 8   151  168   20  156
# 9   131  120    1  175
# 10   79   20   95  186
# 11   20   72   38   72
# 12   49  102   72    0
# 13  171   43  187   26
# 14    8    4  140  116
# 15  124  105  169   85
# 16  143  160   43  124
# 17   11   65  176  128
# 18   33  103  129   37
# 19  160   33   94   45
# 20  139   35  185   45
# 21   72  172  148   59
# 22   96  177  142   63
# 23  131   22  159   59
# 24   53  109   58  161
# 25  146  139  152  189
# 26  131   10   55  118
# 27  189  137  132  129
# 28  151   98  166  158
# 29  171   47   30  107
# 30  156   96   44  114
# 31  115   50  126  193
# 32  199  119  190  166
# 33   19  145  148    5
# 34   17   34  178   33
# 35   93   54   66  114
# 36   73  115  168   74
# 37  153  107  144  172
# 38  159  102   60   62
# 39  174  144    2   55
# 40   35   71  106   19
# 41   84   17  125   33
# 42  148   12   75  149
# 43  174   27  131   94
# 44  172  189   60   43
# 45  131  154  195  182
# 46  190   38   16  184
# 47   89  164   84   79
# 48   41  125   77  187
# 49    7   44    4    1

# %%
dataframe['a'].hist()
# Out:
# <AxesSubplot:>

# %%
dataframe['b'].hist(bins=30) #bins nos genera las columnas deceadas
# Out:
# <AxesSubplot:>

# %%
dataframe.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
dataframe['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataframe.plot.area(alpha=0.3)
# Out:
# <AxesSubplot:>

# %%
dataframe.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dataframe.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
dataframe.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
dataframe.plot.scatter(x='a', y='b',c='c',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
dataframe.plot.box()
# Out:
# <AxesSubplot:>

# %%
dataframe.plot.hexbin(x='a',y='b',gridsize=12)#gridsize le da el tamaño
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
dataframe.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dataframe.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
